# %% [markdown]
# <a href="https://colab.research.google.com/github/Indirajith-jithu/ArithmeticGPT/blob/Indirajith-jithu-patch-1/basic_math.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# np.array(list("697500000002760930835000617001687003000000002580012000070145200900806351050300748")).reshape(9,9)
# Out:
# array([['6', '9', '7', '5', '0', '0', '0', '0', '0'],
#        ['0', '0', '2', '7', '6', '0', '9', '3', '0'],
#        ['8', '3', '5', '0', '0', '0', '6', '1', '7'],
#        ['0', '0', '1', '6', '8', '7', '0', '0', '3'],
#        ['0', '0', '0', '0', '0', '0', '0', '0', '2'],
#        ['5', '8', '0', '0', '1', '2', '0', '0', '0'],
#        ['0', '7', '0', '1', '4', '5', '2', '0', '0'],
#        ['9', '0', '0', '8', '0', '6', '3', '5', '1'],
#        ['0', '5', '0', '3', '0', '0', '7', '4', '8']], dtype='<U1')

# %%
 # !pip install datasets==3.6.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ...

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F



device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# from datasets import load_dataset

# ds = load_dataset("EleutherAI/arithmetic", "arithmetic_1dc")

# %%
# # full data

# df = ds['validation'].to_pandas()

# data = df['context'].str.split("is", expand=True)[1].str.split("?", expand=True)[0] + "="+ \
#         df['completion']

# data = data.str.replace(" ", "", regex=False).tolist()

# %%
from math import perm

p_numbers = list(range(9))
n_numbers = list(range(9))

p_num = [f"+{i}" for i in p_numbers]
n_num = [f"-{i}" for i in n_numbers]

my_list = p_num + n_num


n = len(my_list)
r = 4

if r is None:
    r = n

count = perm(n, r)
print(f"The number of permutations is: {count}")


import itertools

my_list = my_list
all_perms = itertools.permutations(my_list, r)

data = []
for p in all_perms:
    context = "".join(p)
    datum = context + "=" + str(eval(context)).zfill(3)
    data.append(datum)

print('demo data',data[0])
print(len(data))

import random
random.shuffle(data)
# Out:
# The number of permutations is: 73440
# demo data +0+1+2+3=006
# 73440

# %%
99+99+99
# Out:
# 297

# %%
data[0]
# Out:
# '+5+2-4+7=010'

# %%
PAD = "<PAD>"
EOD = "<EOD>"

chars = sorted(list(set("".join(data)))) + [PAD, EOD]
vocab_size = len(chars)

stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for ch, i in stoi.items()}

pad_id = stoi[PAD]
eod_id = stoi[EOD]
eq_id = stoi["="]



encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join(itos[i] for i in l if itos[i] != PAD)

# %%
encoded = [encode(s) + [eod_id] for s in data]

max_len = max(len(s) for s in encoded)

print("max sep len :",max_len)
padded = [
    seq + [pad_id] * (max_len - len(seq))
    for seq in encoded
]

dataset = torch.tensor(padded, dtype=torch.long)


# train / val split
n = int(0.98 * len(dataset))
train_data = dataset[:n]
val_data = dataset[n:]

print(f"Train data size: {len(train_data)}")
print(f"Val data size: {len(val_data)}")
# Out:
# max sep len : 13
# Train data size: 71971
# Val data size: 1469

# %%
def get_batch(split, batch_size):
    data = train_data if split == "train" else val_data

    while True:
        ix = torch.randint(0, len(data), (batch_size,))
        batch = data[ix]

        x = batch[:, :-1]
        y = batch[:, 1:]

        if (y != pad_id).any():
            break

    return x.to(device), y.to(device)

# %%
# get_batch('train')

# %%
### model

# %%
class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)

        self.register_buffer(
            "tril", torch.tril(torch.ones(block_size, block_size))
        )

        self.dropout = nn.Dropout(dropout)

    def forward(self, x, attn_mask=None):
        B, T, C = x.shape

        k = self.key(x)
        q = self.query(x)

        wei = q @ k.transpose(-2, -1) * (k.shape[-1] ** -0.5)

        # causal mask
        wei = wei.masked_fill(self.tril[:T, :T] == 0, -1e4)

        # key  mask
        # wei = wei.masked_fill(attn_mask[:, None, :] == 0, -1e4)
        # query  mask
        # wei = wei.masked_fill(attn_mask[:, :, None] == 0, -1e4)

        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)

        v = self.value(x)
        out = wei @ v

        # zero out PAD queries
        # out = out * attn_mask[:, :, None]

        return out

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(num_heads * head_size, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, attn_mask):
        out = torch.cat([h(x, attn_mask) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

# %%
class FeedForward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

# %%
class Block(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x, attn_mask=None):
        x = x + self.sa(self.ln1(x), attn_mask)
        x = x + self.ffwd(self.ln2(x))
        return x

# %%
class GPTLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()

        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)

        self.blocks = nn.ModuleList(
            [Block(n_embd, n_head) for _ in range(n_layer)]
        )

        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward_omg(self, idx, targets=None):
      B, T = idx.shape

      # ---- Attention mask (for padding) ----
      attn_mask = (idx != pad_id)

      # ---- Embeddings ----
      tok_emb = self.token_embedding_table(idx)  # (B, T, C)
      pos_emb = self.position_embedding_table(
          torch.arange(T, device=idx.device)
      )  # (T, C)

      x = tok_emb + pos_emb

      # ---- Transformer blocks ----
      for block in self.blocks:
          x = block(x, attn_mask)

      x = self.ln_f(x)
      logits = self.lm_head(x)  # (B, T, vocab)

      loss = None

      if targets is not None:

          # -----------------------------------------
          # 1) Ignore PAD tokens
          # -----------------------------------------
          loss_mask = (targets != pad_id)  # (B, T)

          # -----------------------------------------
          # 2) Find "=" position per sequence
          # -----------------------------------------
          eq_mask = (idx == eq_id)                 # (B, T)
          eq_pos = torch.argmax(eq_mask.int(), dim=1)  # (B,)

          # -----------------------------------------
          # 3) Keep only tokens AFTER "="
          # -----------------------------------------
          pos = torch.arange(T, device=idx.device).unsqueeze(0)  # (1, T)
          after_eq = pos > eq_pos.unsqueeze(1)                   # (B, T)

          loss_mask = loss_mask & after_eq

          # -----------------------------------------
          # 4) Cross entropy
          # -----------------------------------------
          logits_flat = logits.reshape(-1, vocab_size)
          targets_flat = targets.reshape(-1)
          mask_flat = loss_mask.reshape(-1)

          loss_all = F.cross_entropy(
              logits_flat,
              targets_flat,
              reduction="none",
          )

          loss = (loss_all * mask_flat).sum() / mask_flat.sum().clamp(min=1)

      return logits, loss


    def forward(self, idx, targets=None):
      B, T = idx.shape

      # ---- Embeddings ----
      tok_emb = self.token_embedding_table(idx)  # (B, T, C)
      pos = torch.arange(T, device=idx.device)
      pos_emb = self.position_embedding_table(pos)  # (T, C)

      x = tok_emb + pos_emb  # (B, T, C)

      # ---- Transformer blocks ----
      for block in self.blocks:
          x = block(x)  # normal causal block

      x = self.ln_f(x)
      logits = self.lm_head(x)  # (B, T, vocab_size)

      loss = None
      if targets is not None:
          # standard cross entropy
          logits = logits.reshape(-1, vocab_size)
          targets = targets.reshape(-1)

          loss = F.cross_entropy(
              logits,
              targets,
              ignore_index=pad_id  # ignore padding tokens
          )

      return logits.view(B, T, -1), loss

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    batch_size = 64
    for split in ["train", "val"]:
        losses = torch.zeros(eval_iters)

        for k in range(eval_iters):
            xb, yb = get_batch(split, batch_size)
            _, loss = model(xb, yb)
            losses[k] = loss.item()

        out[split] = losses.mean()

    model.train()
    return out

# %%
5e-3
# Out:
# 0.005

# %%
learning_rate
# Out:
# 0.0001

# %%
# training
max_iters      = 20000
eval_iters     = 200
eval_interval  = 150
batch_size     = 65536

learning_rate  = 0.005

# model
n_embd   = 4                  # must be divisible by n_head
n_head   = 4
n_layer  = 2
dropout  = 0.01                  # lower dropout = better memorization

# context
block_size = max_len            # full equation including "=" and result

# device
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
model = GPTLanguageModel().to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=max_iters//2
)

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters: {total_params}")
# Out:
# Total parameters: 659

# %%
# %%time


for iter in range(max_iters):
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"{iter:^6}: train {losses['train']:.4f}, val {losses['val']:.4f}", end=" : ")
        acc = evaluate_value(
                    model,
                    data,
                    encode,
                    decode,
                    generate,
                    device,
                    n_samples=100
                )

        print("Value Accuracy:", acc, end="\n")

    xb, yb = get_batch("train", batch_size)
    _, loss = model(xb, yb)

    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
    # scheduler.step()
# Out:
#   0   : train 2.8922, val 2.8936 : Value Accuracy: 0.0
#  150  : train 1.3157, val 1.3156 : Value Accuracy: 0.02
#  300  : train 1.1881, val 1.1906 : Value Accuracy: 0.07
#  450  : train 1.1754, val 1.1774 : Value Accuracy: 0.03
#  600  : train 1.1720, val 1.1754 : Value Accuracy: 0.03
#  750  : train 1.1669, val 1.1690 : Value Accuracy: 0.03
#  900  : train 1.1643, val 1.1669 : Value Accuracy: 0.03
#  1050 : train 1.1598, val 1.1618 : Value Accuracy: 0.04
#  1200 : train 1.1573, val 1.1592 : Value Accuracy: 0.06
#  1350 : train 1.1548, val 1.1573 : Value Accuracy: 0.04
#  1500 : train 1.1520, val 1.1533 : Value Accuracy: 0.07
#  1650 : train 1.1491, val 1.1515 : Value Accuracy: 0.06
#  1800 : train 1.1516, val 1.1540 : Value Accuracy: 0.04
#  1950 : train 1.1472, val 1.1499 : Value Accuracy: 0.04
#  2100 : train 1.1464, val 1.1480 : Value Accuracy: 0.06
#  2250 : train 1.1472, val 1.1482 : Value Accuracy: 0.03
#  2400 : train 1.1446, val 1.1468 : Value Accuracy: 0.04
# ...

# %%
import torch
import os

save_dir = './checkpoints_jithu'
os.makedirs(save_dir, exist_ok=True)

# Save the final model and optimizer (optional scheduler)
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),   # optional if you want to resume later
    'scheduler_state_dict': scheduler.state_dict()    # optional
}, os.path.join(save_dir, 'final_model.pt'))

print("Training complete. Model saved to ./checkpoints/final_model.pt")
# Out:
# Training complete. Model saved to ./checkpoints/final_model.pt

# %%
# %%time
# xb, yb = get_batch("train")
# _, loss = model(xb, yb)

# %%
@torch.no_grad()
def generate(model, idx, max_new_tokens, temperature=1.0):
    model.eval()

    for _ in range(max_new_tokens):
        idx_cond = idx[:, -block_size:]
        logits, _ = model(idx_cond)

        logits = logits[:, -1, :] / temperature
        probs = F.softmax(logits, dim=-1)

        # idx_next = torch.multinomial(probs, 1)
        idx_next = torch.argmax(probs, dim=-1, keepdim=True)
        idx = torch.cat([idx, idx_next], dim=1)

        if (idx_next == eod_id).all():
            break

    return idx

@torch.no_grad()
def generate(model, idx, max_new_tokens=3, temperature=1.0):
    model.eval()

    B = idx.size(0)
    finished = torch.zeros(B, dtype=torch.bool, device=idx.device)

    for _ in range(max_new_tokens):

        idx_cond = idx[:, -block_size:]
        logits, _ = model(idx_cond)

        logits = logits[:, -1, :] / temperature
        probs = F.softmax(logits, dim=-1)

        idx_next = torch.argmax(probs, dim=-1)

        # force finished sequences to keep producing eod
        idx_next = torch.where(
            finished,
            torch.full_like(idx_next, eod_id),
            idx_next
        )

        idx = torch.cat([idx, idx_next.unsqueeze(1)], dim=1)

        # update finished mask
        finished |= (idx_next == eod_id)

        # stop if all finished
        if finished.all():
            break

    return idx


# @torch.no_grad()
# def generate(
#     model,
#     idx,
#     max_new_tokens,
#     pre_temp=1.0,
#     post_temp=0.01
# ):
#     model.eval()
#     eq_id = stoi["="]
#     for _ in range(max_new_tokens):
#         idx_cond = idx[:, -block_size:]
#         logits, _ = model(idx_cond)

#         logits = logits[:, -1, :]  # (B, vocab)

#         # detect "=" in each sequence
#         has_equal = (idx == eq_id).any(dim=1)  # (B,)

#         # apply per-sample temperature
#         temps = torch.where(
#             has_equal,
#             torch.tensor(post_temp, device=idx.device),
#             torch.tensor(pre_temp, device=idx.device)
#         )

#         logits = logits / temps.unsqueeze(1)
#         probs = F.softmax(logits, dim=-1)

#         idx_next = torch.multinomial(probs, 1)
#         idx = torch.cat([idx, idx_next], dim=1)

#         # stop if all sequences ended
#         if (idx_next == eod_id).all():
#             break

#     return idx

# %%
t = val_data[random.randint(0,len(val_data)-1)].to(device)
t = train_data[random.randint(0,len(train_data)-1)].to(device)

c_idx = eq_id
pos = (t == c_idx).nonzero(as_tuple=True)[0].item()
left = t[:pos+1]


context = torch.tensor([encode("+2-1-4=")], device=device)
context = left.unsqueeze(dim=0) #val_data[:9].to(device)
out = generate(
    model,
    context,
    max_new_tokens=30
)
res = decode(out[-1].tolist())
print(res)
print(eval(res.split("=")[0]))
# Out:
# -3-0+8-8=2<EOD>
# -3

# %%
acc = evaluate_value(
            model,
            data,
            encode,
            decode,
            generate,
            device,
            n_samples=100
        )

print("Value Accuracy:", acc, end=" - ")
# Out:
# Value Accuracy: 0.0 -

# %%
def evaluate_value(model, val_text, encode, decode, generate, device, n_samples=40):
    model.eval()

    correct = 0

    # ---- precompute expressions and truths ----
    exprs = []
    truths = []

    for i in range(n_samples):
        sample = val_text[i]
        eq_idx = sample.find("=")
        expr = sample[:eq_idx]
        exprs.append(expr)
        truths.append(str(eval(expr)).zfill(3))

    # ---- evaluation ----
    with torch.no_grad():
        for i in range(n_samples):

            x = torch.tensor(
                encode(exprs[i] + "="),
                device=device
            ).unsqueeze(0)

            out = generate(model, x)
            s = decode(out[0].tolist())

            # ---- fast extract after '=' ----
            eq_idx = s.find("=")
            if eq_idx == -1:
                continue

            after = s[eq_idx + 1:]

            j = 0
            while j < len(after) and (after[j].isdigit() or after[j] == "-"):
                j += 1

            if j == 0:
                continue

            pred = after[:j]#[::-1]   # reverse back

            if pred == truths[i]:
                correct += 1

    return correct / n_samples

# %%
import torch
import random
import torch.nn.functional as F

def get_batch_context(data, batch_size, eq_id, device):
    contexts = []

    for _ in range(batch_size):
        t = data[random.randint(0, len(data)-1)].to(device)

        # find "=" position
        pos = (t == eq_id).nonzero(as_tuple=True)[0].item()

        left = t[:pos+1]
        contexts.append(left)

    # pad to same length
    max_len = max([len(x) for x in contexts])
    padded = []

    for x in contexts:
        pad_len = max_len - len(x)
        padded.append(F.pad(x, (0, pad_len), value=pad_id))

    return torch.stack(padded)


# ===== usage =====
batch_size = 32

context = get_batch_context(train_data, batch_size, eq_id, device)

out = generate(
    model,
    context,
    max_new_tokens=30
)

# decode each sample
for i in range(batch_size):
    res = decode(out[i].tolist())
    expr = res.split("=")[0]

    print("Generated:", res)

    try:
        print("Eval:", eval(expr))
    except:
        print("Invalid expression")

    print("-"*40)
# Out:
# Generated: +8-6-5+0=5<EOD>
# Eval: -3
# ----------------------------------------
# Generated: -3+2-6+1=2<EOD>
# Eval: -6
# ----------------------------------------
# Generated: +8+4-1+7=5<EOD>
# Eval: 18
# ----------------------------------------
# Generated: -5-8-1-4=2<EOD>
# Eval: -18
# ----------------------------------------
# Generated: +5-6-2-7=2<EOD>
# Eval: -10
# ----------------------------------------
# Generated: -1-4+7+2=2<EOD>
# Eval: 4
# ----------------------------------------
# Generated: +2-0+3-3=5<EOD>
# Eval: 2
# ----------------------------------------
# Generated: -6+6-2+5=2<EOD>
# Eval: 3
# ----------------------------------------
# Generated: +3+8+0+5=5<EOD>
# Eval: 16
# ----------------------------------------
# Generated: +0-8+1-3=2<EOD>
# Eval: -10
# ----------------------------------------
# Generated: -4+4+5+0=5<EOD>
# Eval: 5
# ----------------------------------------
# Generated: +4+3-5-3=5<EOD>
# Eval: -1
# ----------------------------------------
# ...

# %%
import torch
import random
import torch.nn.functional as F

def get_batch_context_and_target(data, batch_size, eq_id, device):
    contexts = []
    targets = []

    for _ in range(batch_size):
        t = data[random.randint(0, len(data)-1)].to(device)

        pos = (t == eq_id).nonzero(as_tuple=True)[0].item()

        left = t[:pos+1]        # "-8-1+5="
        right = t[pos+1:]      # "4<eod>"

        contexts.append(left)
        targets.append(right)

    max_len = max(len(x) for x in contexts)
    padded = []

    for x in contexts:
        pad_len = max_len - len(x)
        padded.append(F.pad(x, (0, pad_len), value=pad_id))

    return torch.stack(padded), targets


# ===== Evaluation =====
batch_size = 1024
context, targets = get_batch_context_and_target(train_data, batch_size, eq_id, device)

out = generate(model, context, max_new_tokens=10)

correct = 0
wrong = 0

for i in range(batch_size):
    pred = decode(out[i].tolist())

    # split expression and predicted answer
    if "=" not in pred:
        wrong += 1
        continue

    try:
        expr, pred_ans = pred.split("=")
        pred_ans = pred_ans.replace("<eod>", "").strip()

        true_ans = decode(targets[i].tolist()).replace("<eod>", "").strip()

        if pred_ans == true_ans:
            correct += 1
        else:
            wrong += 1

    except:
        wrong += 1


accuracy = correct / batch_size

print("Correct:", correct)
print("Wrong:", wrong)
print("Accuracy:", accuracy)
# Out:
# Correct: 252
# Wrong: 772
# Accuracy: 0.24609375

# %%
import torch
import torch.nn.functional as F

def evaluate_full_dataset(
    model,
    data,
    batch_size,
    eq_id,
    pad_id,
    device,
    max_new_tokens=10
):
    model.eval()

    total_correct = 0
    total_wrong = 0
    total_samples = len(data)

    with torch.no_grad():
        for i in range(0, total_samples, batch_size):

            batch_data = data[i:i+batch_size]

            contexts = []
            targets = []

            # ---- build batch ----
            for t in batch_data:
                t = t.to(device)

                pos = (t == eq_id).nonzero(as_tuple=True)[0].item()

                left = t[:pos+1]
                right = t[pos+1:]

                contexts.append(left)
                targets.append(right)

            # ---- pad ----
            max_len = max(len(x) for x in contexts)
            padded = [
                F.pad(x, (0, max_len - len(x)), value=pad_id)
                for x in contexts
            ]

            context_batch = torch.stack(padded)

            # ---- generate ----
            out = generate(model, context_batch, max_new_tokens=max_new_tokens)

            # ---- evaluate ----
            for j in range(len(batch_data)):
                pred = decode(out[j].tolist())

                if "=" not in pred:
                    total_wrong += 1
                    continue

                try:
                    expr, pred_ans = pred.split("=")
                    pred_ans = pred_ans.replace("<eod>", "").strip()

                    true_ans = decode(targets[j].tolist()).replace("<eod>", "").strip()

                    if pred_ans == true_ans:
                        total_correct += 1
                    else:
                        total_wrong += 1

                except:
                    total_wrong += 1

    accuracy = total_correct / total_samples

    return {
        "total_samples": total_samples,
        "correct": total_correct,
        "wrong": total_wrong,
        "accuracy": accuracy
    }


import torch
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence

def evaluate_full_dataset_fast(
    model,
    data,
    batch_size,
    eq_id,
    eod_id,
    pad_id,
    device,
    max_new_tokens=5
):
    model.eval()

    total_correct = 0
    total_samples = len(data)

    with torch.no_grad():
        for i in range(0, total_samples, batch_size):

            batch_data = data[i:i+batch_size]

            contexts = []
            targets = []

            # ---- build batch ----
            for t in batch_data:
                t = t.to(device)

                pos = (t == eq_id).nonzero(as_tuple=True)[0][0]

                contexts.append(t[:pos+1])     # expression + "="
                targets.append(t[pos+1:])      # answer + <eod>

            # ---- pad batch ----
            context_batch = pad_sequence(
                contexts,
                batch_first=True,
                padding_value=pad_id
            )

            # ---- generate ----
            out = generate(
                model,
                context_batch,
                max_new_tokens=max_new_tokens
            )

            # ---- token-level comparison ----
            for j in range(len(batch_data)):

                pred_seq = out[j]

                # find "=" position in generated output
                eq_pos = (pred_seq == eq_id).nonzero(as_tuple=True)
                if len(eq_pos[0]) == 0:
                    continue  # invalid output

                eq_pos = eq_pos[0][0]

                pred_ans = pred_seq[eq_pos+1:]

                # stop at <eod>
                eod_pos = (pred_ans == eod_id).nonzero(as_tuple=True)
                if len(eod_pos[0]) > 0:
                    pred_ans = pred_ans[:eod_pos[0][0]]

                true_ans = targets[j]

                # remove <eod> from true
                true_eod = (true_ans == eod_id).nonzero(as_tuple=True)
                if len(true_eod[0]) > 0:
                    true_ans = true_ans[:true_eod[0][0]]

                # compare tokens directly
                if torch.equal(pred_ans, true_ans):
                    total_correct += 1

    accuracy = total_correct / total_samples

    return {
        "total_samples": total_samples,
        "correct": total_correct,
        "wrong": total_samples - total_correct,
        "accuracy": accuracy
    }

# %%
# %%time
metrics = evaluate_full_dataset(
    model,
    train_data[:20000],
    batch_size=1024,
    eq_id=eq_id,
    pad_id=pad_id,
    device=device
)

print(metrics)
# Out:
# {'total_samples': 20000, 'correct': 4137, 'wrong': 15863, 'accuracy': 0.20685}
# CPU times: user 5.22 s, sys: 2.97 ms, total: 5.22 s
# Wall time: 5.45 s

# %%
len(val_data)
# Out:
# 1469

# %%
# %%time
metrics = evaluate_full_dataset_fast(
    model,
    train_data,
    batch_size=512,
    eq_id=eq_id,
    pad_id=pad_id,
    device=device,
    eod_id=eod_id
)

print(metrics)
# Out:
# {'total_samples': 4798, 'correct': 1038, 'wrong': 3760, 'accuracy': 0.21634014172571905}
# CPU times: user 2.48 s, sys: 5.02 ms, total: 2.49 s
# Wall time: 2.49 s

# %% [markdown]
# version 2 **test**

# %%
from math import perm

p_numbers = list(range(9))
n_numbers = list(range(9))

p_num = [f"+{i}" for i in p_numbers]
n_num = [f"-{i}" for i in n_numbers]

my_list = p_num + n_num


n = len(my_list)
r = 4

if r is None:
    r = n

count = perm(n, r)
print(f"The number of permutations is: {count}")


import itertools

my_list = my_list
all_perms = itertools.permutations(my_list, r)

data = []
for p in all_perms:
    context = "".join(p)
    datum = context + "=" + str(eval(context)).zfill(3) + '<eod>'
    data.append(datum)

print('demo data',data[0])
print(len(data))

import random
random.shuffle(data)
# Out:
# The number of permutations is: 73440
# demo data +0+1+2+3=006<eod>
# 73440

# %%
len(data)
# Out:
# 73440

# %%
data[0]
# Out:
# '+4-3+3+1=500<eod>'

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import random
import math

device = "cuda" if torch.cuda.is_available() else "cpu"

# training config
batch_size = 256
block_size = 20
learning_rate = 3e-4
max_iters = 6000
eval_interval = 250

n_embd = 128
n_head = 4
n_layer = 6
dropout = 0.0


def generate_sample(r=4):
    expr = ""
    for _ in range(r):
        sign = random.choice(["+", "-"])
        digit = random.randint(0, 8)
        expr += f"{sign}{digit}"

    result = eval(expr)
    result_str = str(result).zfill(3)
    result_str = result_str[::-1]  # reverse trick

    return expr + "=" + result_str + "<eod>"


def build_dataset(n_samples):
    return [generate_sample(4) for _ in range(n_samples)]

# data = build_dataset(60000)
random.shuffle(data)

split = int(0.9 * len(data))
train_text = data[:split]
val_text = data[split:]

# %%
chars = sorted(list(set("".join(data))))
stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for ch, i in stoi.items()}

vocab_size = len(stoi)
pad_token = "<"
pad_id = stoi[pad_token]

def encode(s):
    return [stoi[c] for c in s]

def decode(l):
    return "".join([itos[i] for i in l])

def encode_dataset(dataset):
    return [torch.tensor(encode(s), dtype=torch.long) for s in dataset]

train_data = encode_dataset(train_text)
val_data = encode_dataset(val_text)

# %%
def get_batch(split):
    data = train_data if split == "train" else val_data
    batch = random.sample(data, batch_size)

    x = torch.stack([item[:-1] for item in batch])
    y = torch.stack([item[1:] for item in batch])

    return x.to(device), y.to(device)

# %%
class TransformerModel(nn.Module):
    def __init__(self, vocab_size,
                 n_embd=128,
                 n_head=4,
                 n_layer=6,
                 dropout=0.0):
        super().__init__()

        self.token_emb = nn.Embedding(vocab_size, n_embd)
        self.pos_emb = nn.Embedding(block_size, n_embd)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=n_embd,
            nhead=n_head,
            dropout=dropout,
            batch_first=True
        )

        self.transformer = nn.TransformerEncoder(
            encoder_layer,
            num_layers=n_layer
        )

        self.ln = nn.LayerNorm(n_embd)
        self.fc = nn.Linear(n_embd, vocab_size)

        self.loss_fn = nn.CrossEntropyLoss(ignore_index=-100)

    def forward(self, x, targets=None):
        B, T = x.shape

        positions = torch.arange(T, device=x.device)
        positions = positions.unsqueeze(0).expand(B, T)

        tok_emb = self.token_emb(x)
        pos_emb = self.pos_emb(positions)

        h = tok_emb + pos_emb

        # causal mask
        mask = torch.triu(
            torch.ones(T, T, device=x.device),
            diagonal=1
        )
        mask = mask.masked_fill(mask == 1, float("-inf"))

        h = self.transformer(h, mask=mask)

        h = self.ln(h)
        logits = self.fc(h)

        loss = None
        if targets is not None:
            loss = self.loss_fn(
                logits.reshape(-1, vocab_size),
                targets.reshape(-1)
            )

        return logits, loss

# %%
model = TransformerModel(
    vocab_size=vocab_size,
    n_embd=8,
    n_head=2,
    n_layer=2,
    dropout=0.0
).to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4)

# %%
@torch.no_grad()
def evaluate():
    model.eval()

    xb, yb = get_batch("val")
    _, loss = model(xb, yb)

    model.train()
    return loss.item()

# %%
print(f"Step {step:^6} jij", end=" - ")
# Out:
# Step  831   jij -

# %%
max_iters = 12000
eval_interval = 550

for step in range(max_iters):

    xb, yb = get_batch("train")

    logits, loss = model(xb, yb)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if step % eval_interval == 0:
        val_loss = evaluate()
        print(f"Step {step:^6}", end=" - ")
        print(f"Train Loss: {loss.item():.4f}",  end=" - ")
        print(f"Val Loss:   {val_loss:.4f}",  end=" - ")
        acc = evaluate_value(
            model,
            val_text,
            encode,
            decode,
            generate,
            device,
            n_samples=100
        )

        print("Value Accuracy:", acc, end=" - ")
        print("-" * 30)

print("Training Complete.")
# Out:
# Step   0    - Train Loss: 0.6952 - Val Loss:   0.6946 - Value Accuracy: 0.96 - ------------------------------
# Step  550   - Train Loss: 0.6924 - Val Loss:   0.7166 - Value Accuracy: 0.7 - ------------------------------
# Step  1100  - Train Loss: 0.7026 - Val Loss:   0.7068 - Value Accuracy: 0.87 - ------------------------------
# Step  1650  - Train Loss: 0.6941 - Val Loss:   0.6988 - Value Accuracy: 0.86 - ------------------------------
# Step  2200  - Train Loss: 0.6870 - Val Loss:   0.6934 - Value Accuracy: 0.97 - ------------------------------
# Step  2750  - Train Loss: 0.6882 - Val Loss:   0.6961 - Value Accuracy: 0.97 - ------------------------------
# Step  3300  - Train Loss: 0.6836 - Val Loss:   0.6857 - Value Accuracy: 0.98 - ------------------------------
# Step  3850  - Train Loss: 0.7054 - Val Loss:   0.7128 - Value Accuracy: 0.79 - ------------------------------
# ...

# %%
acc = evaluate_value(
            model,
            val_text,
            encode,
            decode,
            generate,
            device,
            n_samples=4000
        )

print("Value Accuracy:", acc)
# Out:
# Value Accuracy: 0.99575

# %%
stoi
# Out:
# {'+': 0,
#  '-': 1,
#  '0': 2,
#  '1': 3,
#  '2': 4,
#  '3': 5,
#  '4': 6,
#  '5': 7,
#  '6': 8,
#  '7': 9,
#  '8': 10,
#  '9': 11,
#  '=': 12,
#  '<PAD>': 13,
#  '<EOD>': 14}

# %%
@torch.no_grad()
def generate(model, idx, max_new_tokens=6):
    model.eval()

    for _ in range(max_new_tokens):
        logits, _ = model(idx)
        logits = logits[:, -1, :]
        next_token = torch.argmax(logits, dim=-1, keepdim=True)

        idx = torch.cat([idx, next_token], dim=1)

        # stop if <eod> produced
        if next_token.item() == stoi["<EOD>"]:
            break

    return idx

# %%
@torch.no_grad()
def evaluate_value(model, n_samples=1000):
    model.eval()

    correct = 0

    for i in range(n_samples):
        sample = val_text[i]   # deterministic order

        expr = sample.split("=")[0]
        true_value = eval(expr)

        # feed only the expression + "="
        input_str = expr + "="
        x = torch.tensor(encode(input_str), device=device).unsqueeze(0)

        out = generate(model, x)

        decoded = decode(out[0].tolist())

        # extract predicted reversed answer
        try:
            pred_part = decoded.split("=")[1]
            pred_part = pred_part.replace("<eod>", "")
            pred_value = int(pred_part[::-1])  # reverse back
        except:
            continue  # skip malformed output

        if pred_value == true_value:
            correct += 1

    acc = correct / n_samples
    print(f"Value Accuracy: {acc:.4f}")
    return acc

# %%
evaluate_value(model, n_samples=200)
# Out:
# Value Accuracy: 0.0000
# 0.0

# %%
import re
def find_truth(s, expr):
  after_equal = s.split("=")[1]
  number_str = after_equal[:-1]
  pred = number_str[::-1]
  return str(eval(expr)).zfill(3) == pred

acc = []
for i in range(40):
    sample = val_text[i]
    expr = sample.split("=")[0]
    x = torch.tensor(encode(expr + "="), device=device).unsqueeze(0)
    out = generate(model, x)
    s = decode(out[0].tolist())
    acc.append(find_truth(s, expr))
acc[:10]
# Out:
# [True, True, True, True, True, True, True, True, True, True]

# %%
sum(acc) / len(acc)
# Out:
# 1.0

# %%
def evaluate_value(model, val_text, encode, decode, generate, device, n_samples=40):
    model.eval()

    correct = 0

    # ---- precompute expressions and truths ----
    exprs = []
    truths = []

    for i in range(n_samples):
        sample = val_text[i]
        eq_idx = sample.find("=")
        expr = sample[:eq_idx]
        exprs.append(expr)
        truths.append(str(eval(expr)).zfill(3))

    # ---- evaluation ----
    with torch.no_grad():
        for i in range(n_samples):

            x = torch.tensor(
                encode(exprs[i] + "="),
                device=device
            ).unsqueeze(0)

            out = generate(model, x)
            s = decode(out[0].tolist())

            # ---- fast extract after '=' ----
            eq_idx = s.find("=")
            if eq_idx == -1:
                continue

            after = s[eq_idx + 1:]

            j = 0
            while j < len(after) and (after[j].isdigit() or after[j] == "-"):
                j += 1

            if j == 0:
                continue

            pred = after[:j]#[::-1]   # reverse back

            if pred == truths[i]:
                correct += 1

    return correct / n_samples


import torch

def evaluate_value_batched(
    model,
    val_text,
    encode,
    decode,
    generate,
    device,
    n_samples=200,
    batch_size=32
):
    model.eval()

    # --------- prepare expressions + truths ----------
    exprs = []
    truths = []

    for i in range(n_samples):
        sample = val_text[i]
        eq_idx = sample.find("=")
        expr = sample[:eq_idx]
        exprs.append(expr)
        truths.append(str(eval(expr)).zfill(3))

    correct = 0

    # --------- batched evaluation ----------
    with torch.no_grad():
        for i in range(0, n_samples, batch_size):

            batch_exprs = exprs[i:i+batch_size]
            batch_truths = truths[i:i+batch_size]

            # encode all
            encoded = [encode(expr + "=") for expr in batch_exprs]
            max_len = max(len(e) for e in encoded)

            # pad
            x = torch.zeros(len(encoded), max_len, dtype=torch.long, device=device)
            for j, e in enumerate(encoded):
                x[j, :len(e)] = torch.tensor(e, device=device)

            # generate in batch
            out = generate(model, x)

            # decode each result
            for j in range(len(out)):

                s = decode(out[j].tolist())

                eq_idx = s.find("=")
                if eq_idx == -1:
                    continue

                after = s[eq_idx + 1:]

                k = 0
                while k < len(after) and (after[k].isdigit() or after[k] == "-"):
                    k += 1

                if k == 0:
                    continue

                pred = after[:k][::-1]

                if pred == batch_truths[j]:
                    correct += 1

    return correct / n_samples

# %%
acc = evaluate_value(
    model,
    val_text,
    encode,
    decode,
    generate,
    device,
    n_samples=400
)

print("Value Accuracy:", acc)
# Out:
# Value Accuracy: 0.9975

# %%
acc = evaluate_value_batched(
    model,
    val_text,
    encode,
    decode,
    generate,
    device,
    n_samples=200,
    batch_size=32
)

print("Value Accuracy:", acc)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1398572059.py in <cell line: 0>()
# ----> 1 acc = evaluate_value_batched(
#       2     model,
#       3     val_text,
#       4     encode,
#       5     decode,
#
# /tmp/ipython-input-2045151314.py in evaluate_value_batched(model, val_text, encode, decode, generate, device, n_samples, batch_size)
#      93
#      94             # generate in batch
# ---> 95             out = generate(model, x)
#      96
#      97             # decode each result
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     122         # pyrefly: ignore [bad-context-manager]
#     123         with ctx_factory():
# --> 124             return func(*args, **kwargs)
#     125
#     126     return decorate_context
#
# ...

# %%
expr = "+8+4+8-7"
x = torch.tensor(encode(expr + "="), device=device).unsqueeze(0)
out = generate(model, x)
s = decode(out[0].tolist())
s
print(s, eval(expr))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1656353997.py in <cell line: 0>()
#       1 expr = "+8+4+8-7"
#       2 x = torch.tensor(encode(expr + "="), device=device).unsqueeze(0)
# ----> 3 out = generate(model, x)
#       4 s = decode(out[0].tolist())
#       5 s
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     122         # pyrefly: ignore [bad-context-manager]
#     123         with ctx_factory():
# --> 124             return func(*args, **kwargs)
#     125
#     126     return decorate_context
#
# TypeError: generate() missing 1 required positional argument: 'max_new_tokens'
