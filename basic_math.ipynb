# %% [markdown]
# <a href="https://colab.research.google.com/github/Indirajith-jithu/ArithmeticGPT/blob/Indirajith-jithu-patch-1/basic_math.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.array(list("697500000002760930835000617001687003000000002580012000070145200900806351050300748")).reshape(9,9)
# Out:
# array([['6', '9', '7', '5', '0', '0', '0', '0', '0'],
#        ['0', '0', '2', '7', '6', '0', '9', '3', '0'],
#        ['8', '3', '5', '0', '0', '0', '6', '1', '7'],
#        ['0', '0', '1', '6', '8', '7', '0', '0', '3'],
#        ['0', '0', '0', '0', '0', '0', '0', '0', '2'],
#        ['5', '8', '0', '0', '1', '2', '0', '0', '0'],
#        ['0', '7', '0', '1', '4', '5', '2', '0', '0'],
#        ['9', '0', '0', '8', '0', '6', '3', '5', '1'],
#        ['0', '5', '0', '3', '0', '0', '7', '4', '8']], dtype='<U1')

# %%
 # !pip install datasets==3.6.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 9.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ...

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F



device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# from datasets import load_dataset

# ds = load_dataset("EleutherAI/arithmetic", "arithmetic_1dc")

# %%
# # full data

# df = ds['validation'].to_pandas()

# data = df['context'].str.split("is", expand=True)[1].str.split("?", expand=True)[0] + "="+ \
#         df['completion']

# data = data.str.replace(" ", "", regex=False).tolist()

# %%
p_numbers = list(range(9))
n_numbers = list(range(9))

p_num = [f"+{i}" for i in p_numbers]
n_num = [f"-{i}" for i in n_numbers]

my_list = p_num + n_num

# %%
from math import perm

n = len(my_list)
r = 3

if r is None:
    r = n

count = perm(n, r)
print(f"The number of permutations is: {count}")
# Out:
# The number of permutations is: 4896

# %%
str(eval("9+9+9")).zfill(3)
# Out:
# '027'

# %%
import itertools

my_list = my_list
all_perms = itertools.permutations(my_list, r)

# print(f"All permutations of {my_list}:")
data = []
for p in all_perms:
    context = "".join(p)
    datum = context + "=" + str(eval(context)).zfill(3)
    data.append(datum)

print('demo data',data[0])
print(len(data))

import random
random.shuffle(data)
# Out:
# demo data +0+1+2=003
# 4896

# %%
99+99+99
# Out:
# 297

# %%
data[0]
# Out:
# '-3+4-2=-01'

# %%
PAD = "<PAD>"
EOD = "<EOD>"

chars = sorted(list(set("".join(data)))) + [PAD, EOD]
vocab_size = len(chars)

stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for ch, i in stoi.items()}

pad_id = stoi[PAD]
eod_id = stoi[EOD]
eq_id = stoi["="]



encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join(itos[i] for i in l if itos[i] != PAD)

# %%
encoded = [encode(s) + [eod_id] for s in data]

max_len = max(len(s) for s in encoded)

print("max sep len :",max_len)
padded = [
    seq + [pad_id] * (max_len - len(seq))
    for seq in encoded
]

dataset = torch.tensor(padded, dtype=torch.long)


# train / val split
n = int(0.98 * len(dataset))
train_data = dataset[:n]
val_data = dataset[n:]

print(f"Train data size: {len(train_data)}")
print(f"Val data size: {len(val_data)}")
# Out:
# max sep len : 11
# Train data size: 4798
# Val data size: 98

# %%
def get_batch(split, batch_size):
    data = train_data if split == "train" else val_data

    while True:
        ix = torch.randint(0, len(data), (batch_size,))
        batch = data[ix]

        x = batch[:, :-1]
        y = batch[:, 1:]

        if (y != pad_id).any():
            break

    return x.to(device), y.to(device)

# %%
# get_batch('train')

# %%
### model

# %%
class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)

        self.register_buffer(
            "tril", torch.tril(torch.ones(block_size, block_size))
        )

        self.dropout = nn.Dropout(dropout)

    def forward(self, x, attn_mask):
        B, T, C = x.shape

        k = self.key(x)
        q = self.query(x)

        wei = q @ k.transpose(-2, -1) * (k.shape[-1] ** -0.5)

        # causal mask
        wei = wei.masked_fill(self.tril[:T, :T] == 0, -1e4)

        # key  mask
        wei = wei.masked_fill(attn_mask[:, None, :] == 0, -1e4)
        # query  mask
        # wei = wei.masked_fill(attn_mask[:, :, None] == 0, -1e4)

        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)

        v = self.value(x)
        out = wei @ v

        # zero out PAD queries
        out = out * attn_mask[:, :, None]

        return out

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(num_heads * head_size, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, attn_mask):
        out = torch.cat([h(x, attn_mask) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

# %%
class FeedForward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

# %%
class Block(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x, attn_mask):
        x = x + self.sa(self.ln1(x), attn_mask)
        x = x + self.ffwd(self.ln2(x))
        return x

# %%
class GPTLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()

        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)

        self.blocks = nn.ModuleList(
            [Block(n_embd, n_head) for _ in range(n_layer)]
        )

        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # padding mask for attention
        attn_mask = (idx != pad_id)

        # embeddings
        tok_emb = self.token_embedding_table(idx)                  # (B, T, C)
        pos_emb = self.position_embedding_table(
            torch.arange(T, device=idx.device)
        )                                                          # (T, C)

        x = tok_emb + pos_emb

        # transformer blocks
        for block in self.blocks:
            x = block(x, attn_mask)

        x = self.ln_f(x)
        logits = self.lm_head(x)                                   # (B, T, vocab)

        loss = None
        if targets is not None:

            # --------------------------------------------------
            # 1) base mask → ignore PAD targets
            # --------------------------------------------------
            loss_mask = (targets != pad_id)                        # (B, T)

            # --------------------------------------------------
            # 2) find first "=" position in each sequence
            # --------------------------------------------------
            eq_mask = (idx == eq_id)                               # (B, T)
            has_eq = eq_mask.any(dim=1)                            # (B,)
            eq_pos = torch.argmax(eq_mask.int(), dim=1)            # (B,)

            # --------------------------------------------------
            # 3) build position indices
            # --------------------------------------------------
            pos = torch.arange(T, device=idx.device).unsqueeze(0)  # (1, T)

            # mask everything BEFORE and INCLUDING "="
            before_eq = pos <= eq_pos.unsqueeze(1)                 # (B, T)

            # apply only where "=" exists
            loss_mask = loss_mask & (~before_eq | ~has_eq.unsqueeze(1))

            # --------------------------------------------------
            # 4) prevent EARLY <EOD> right after "="
            # --------------------------------------------------
            after_eq = pos == (eq_pos.unsqueeze(1) + 1)            # (B, T)
            early_eod = after_eq & (targets == eod_id)

            loss_mask = loss_mask & (~early_eod)

            # --------------------------------------------------
            # 5) compute masked cross-entropy
            # --------------------------------------------------
            logits_flat = logits.reshape(-1, vocab_size)
            targets_flat = targets.reshape(-1)
            mask_flat = loss_mask.reshape(-1)

            loss_all = F.cross_entropy(
                logits_flat,
                targets_flat,
                reduction="none",
            )

            # safe masked mean
            loss = (loss_all * mask_flat).sum() / mask_flat.sum().clamp(min=1)

        return logits, loss

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    batch_size = 64
    for split in ["train", "val"]:
        losses = torch.zeros(eval_iters)

        for k in range(eval_iters):
            xb, yb = get_batch(split, batch_size)
            _, loss = model(xb, yb)
            losses[k] = loss.item()

        out[split] = losses.mean()

    model.train()
    return out

# %%
# training
max_iters      = 20000
eval_iters     = 200
eval_interval  = 1000
batch_size     = 256

learning_rate  = 1e-3

# model
n_embd   = 64                   # must be divisible by n_head
n_head   = 2
n_layer  = 4
dropout  = 0.1                  # lower dropout = better memorization

# context
block_size = max_len            # full equation including "=" and result

# device
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
model = GPTLanguageModel().to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=max_iters
)

# %%
# import os
# os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters: {total_params}")
# Out:
# Total parameters: 201935

# %%
# %%time


for iter in range(max_iters):
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"{iter}: train {losses['train']:.4f}, val {losses['val']:.4f}")

    xb, yb = get_batch("train", batch_size)
    _, loss = model(xb, yb)

    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
    scheduler.step()
# Out:
# 0: train 2.9941, val 2.9870
# 1000: train 0.2391, val 0.2412

# %%
# %%time
# xb, yb = get_batch("train")
# _, loss = model(xb, yb)

# %%
@torch.no_grad()
def generate(model, idx, max_new_tokens, temperature=1.0):
    model.eval()

    for _ in range(max_new_tokens):
        idx_cond = idx[:, -block_size:]
        logits, _ = model(idx_cond)

        logits = logits[:, -1, :] / temperature
        probs = F.softmax(logits, dim=-1)

        # idx_next = torch.multinomial(probs, 1)
        idx_next = torch.argmax(probs, dim=-1, keepdim=True)
        idx = torch.cat([idx, idx_next], dim=1)

        if (idx_next == eod_id).all():
            break

    return idx



# @torch.no_grad()
# def generate(
#     model,
#     idx,
#     max_new_tokens,
#     pre_temp=1.0,
#     post_temp=0.01
# ):
#     model.eval()
#     eq_id = stoi["="]
#     for _ in range(max_new_tokens):
#         idx_cond = idx[:, -block_size:]
#         logits, _ = model(idx_cond)

#         logits = logits[:, -1, :]  # (B, vocab)

#         # detect "=" in each sequence
#         has_equal = (idx == eq_id).any(dim=1)  # (B,)

#         # apply per-sample temperature
#         temps = torch.where(
#             has_equal,
#             torch.tensor(post_temp, device=idx.device),
#             torch.tensor(pre_temp, device=idx.device)
#         )

#         logits = logits / temps.unsqueeze(1)
#         probs = F.softmax(logits, dim=-1)

#         idx_next = torch.multinomial(probs, 1)
#         idx = torch.cat([idx, idx_next], dim=1)

#         # stop if all sequences ended
#         if (idx_next == eod_id).all():
#             break

#     return idx

# %%
t = val_data[random.randint(0,len(val_data)-1)].to(device)
t = train_data[random.randint(0,len(train_data)-1)].to(device)

c_idx = eq_id
pos = (t == c_idx).nonzero(as_tuple=True)[0].item()
left = t[:pos+1]

# print(decode(left.tolist()))

context = torch.tensor([encode("-8-1+5=")], device=device)
context = left.unsqueeze(dim=0) #val_data[:9].to(device)
out = generate(
    model,
    context,
    max_new_tokens=30
)
res = decode(out[-1].tolist())
print(res)
print(eval(res.split("=")[0]))
# Out:
# -0+1-8=007<EOD>
# -7

# %%
context = val_data[:9].to(device)
context
# Out:
# tensor([[ 1,  3,  1,  7,  1,  8, 12,  1,  3,  4, 14],
#         [ 1,  2,  1,  7,  0, 10, 12,  2,  2,  5, 14],
#         [ 0, 10,  1,  3,  1,  6, 12,  2,  2,  5, 14],
#         [ 0,  5,  0,  7,  1,  2, 12,  2,  2, 10, 14],
#         [ 0,  3,  0,  5,  0,  9, 12,  2,  3,  3, 14],
#         [ 0,  5,  0,  7,  1,  5, 12,  2,  2,  7, 14],
#         [ 1,  6,  1,  4,  0,  2, 12,  1,  2,  8, 14],
#         [ 0,  5,  1,  4,  0,  9, 12,  2,  2, 10, 14],
#         [ 1,  6,  0,  4,  0,  7, 12,  2,  2,  5, 14]], device='cuda:0')

# %%
context = torch.tensor([encode("-6-48+38=")], device=device)
context
# Out:
# tensor([[ 1,  8,  1,  6, 10,  0,  5, 10, 12]], device='cuda:0')

# %%
out[0].tolist()
# Out:
# [0, 11, 2, 10, 1, 3, 8, 15, 8, 13, 17]

# %%
context = torch.tensor([encode(inpu)], device=device)
out = generate(
    model,
    context,
    max_new_tokens=30
)
res = decode(out[0].tolist())
print(res)
# Out:
# (6*5)+3=38<EOD>

# %%
context = torch.tensor([encode("(6+4)*7=")], device=device)
out = generate(
    model,
    context,
    max_new_tokens=30
)
res = decode(out[0].tolist())
print(res)
# Out:
# (6+4)*7=<EOD>

# %%
out = model(context)[0]
out.shape
# Out:
# torch.Size([1, 7, 15])

# %%
out[0,-1].argmax()
# Out:
# tensor(14, device='cuda:0')

# %%
decode([14])
# Out:
# '<EOD>'
